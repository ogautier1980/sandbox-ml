# %% [markdown]
# # Quiz d'Auto-Évaluation - Chapitre 00 : Introduction au Machine Learning
#
# **Instructions** :
# - Ce quiz contient 15 questions pour tester votre compréhension du chapitre
# - Répondez aux questions par vous-même avant de regarder les réponses
# - Les réponses sont dans une cellule masquée à la fin
# - Comptez 1 point par bonne réponse
#
# **Barème** :
# - 13-15 : Excellent ! Vous maîtrisez le chapitre 💪
# - 10-12 : Bien, relisez les sections où vous avez des lacunes
# - 7-9 : Moyen, relisez le chapitre attentivement
# - < 7 : Insuffisant, reprenez le chapitre depuis le début
#
# ---

# %% [markdown]
# ## Questions
#
# ### Question 1 : Définition du Machine Learning
# Selon Tom Mitchell, un programme apprend d'une expérience E par rapport à une tâche T et une mesure de performance P. Parmi les propositions suivantes, laquelle est FAUSSE ?
#
# A) La tâche T représente ce que le système doit accomplir
# B) L'expérience E correspond aux données utilisées pour l'apprentissage
# C) La performance P mesure la qualité du système
# D) Le Machine Learning nécessite toujours de programmer explicitement les règles
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 2 : Apprentissage Supervisé
# Dans l'apprentissage supervisé, quelle est la caractéristique principale des données d'entraînement ?
#
# A) Elles sont très volumineuses
# B) Elles contiennent des labels (étiquettes)
# C) Elles ne contiennent que des images
# D) Elles sont collectées en temps réel
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 3 : Régression vs Classification
# Parmi les tâches suivantes, lesquelles sont des problèmes de RÉGRESSION ?
#
# 1. Prédire le prix d'une maison
# 2. Détecter si un email est un spam
# 3. Prédire la température demain
# 4. Classifier une image de chien ou chat
#
# A) 1 et 3
# B) 2 et 4
# C) 1, 2 et 3
# D) Toutes
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 4 : Apprentissage Non-Supervisé
# Quelle est la différence principale entre apprentissage supervisé et non-supervisé ?
#
# A) Le non-supervisé utilise plus de données
# B) Le non-supervisé n'utilise pas de labels
# C) Le non-supervisé est toujours plus précis
# D) Le non-supervisé ne fonctionne qu'avec des images
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 5 : Train / Validation / Test
# Pourquoi divise-t-on les données en trois ensembles distincts ?
#
# A) Pour augmenter la taille du dataset
# B) Pour éviter l'overfitting et évaluer objectivement le modèle
# C) Parce que c'est obligatoire en Machine Learning
# D) Pour accélérer l'entraînement
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 6 : Overfitting
# Un modèle en overfitting a typiquement :
#
# A) Performance élevée sur train ET test
# B) Performance faible sur train ET test
# C) Performance élevée sur train, faible sur test
# D) Performance faible sur train, élevée sur test
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 7 : Paramètres vs Hyperparamètres
# Quelle affirmation est CORRECTE ?
#
# A) Les paramètres sont choisis par le développeur, les hyperparamètres par le modèle
# B) Les paramètres sont appris par le modèle, les hyperparamètres choisis par le développeur
# C) Paramètres et hyperparamètres sont identiques
# D) Les hyperparamètres n'existent que dans le Deep Learning
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 8 : Feature Engineering
# Qu'est-ce que le feature engineering ?
#
# A) Collecter plus de données
# B) Créer ou transformer des features pour améliorer le modèle
# C) Augmenter le nombre de couches du réseau
# D) Diviser les données en train/test
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 9 : Machine Learning vs Deep Learning
# Quelle caractéristique est typique du DEEP LEARNING (et non du ML classique) ?
#
# A) Nécessite des labels
# B) Apprend les features automatiquement
# C) Peut faire de la classification
# D) Utilise des algorithmes
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 10 : Apprentissage par Renforcement
# Dans l'apprentissage par renforcement, l'agent apprend via :
#
# A) Des exemples étiquetés
# B) Des récompenses et pénalités
# C) Des patterns dans les données
# D) La copie d'un expert humain
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 11 : Pipeline ML
# Quel est l'ORDRE CORRECT des étapes d'un pipeline ML typique ?
#
# A) Modèle → Données → Évaluation → Déploiement
# B) Données → Préparation → Features → Modèle → Évaluation
# C) Évaluation → Modèle → Données → Déploiement
# D) Features → Modèle → Données → Évaluation
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 12 : Compromis Biais-Variance
# Un modèle avec un BIAIS élevé a tendance à :
#
# A) Overfitter les données
# B) Underfitter les données
# C) Bien généraliser
# D) Avoir une variance élevée
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 13 : Éthique et Biais
# Pourquoi les biais dans les données sont-ils problématiques en ML ?
#
# A) Ils ralentissent l'entraînement
# B) Ils augmentent le coût computationnel
# C) Le modèle peut apprendre et amplifier ces biais
# D) Ils empêchent le modèle de converger
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 14 : Validation Croisée
# La validation croisée (cross-validation) permet de :
#
# A) Augmenter la taille du dataset
# B) Accélérer l'entraînement
# C) Obtenir une estimation plus robuste de la performance
# D) Réduire l'overfitting automatiquement
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 15 : Applications du ML
# Parmi ces domaines, lequel N'utilise PAS typiquement le Machine Learning ?
#
# A) Reconnaissance faciale
# B) Traduction automatique
# C) Calcul d'une somme de deux nombres
# D) Détection de fraudes bancaires
#
# **Votre réponse** : ___

# %% [markdown]
# ---
#
# ## Auto-Correction
#
# Avant de regarder les réponses, comptez combien de réponses vous avez données.

# %%
# Entrez vos réponses ici (ex: ['D', 'B', 'A', ...])
mes_reponses = []  # TODO: remplir avec vos réponses

# Réponses correctes (masquées)
reponses_correctes = ['D', 'B', 'A', 'B', 'B', 'C', 'B', 'B', 'B', 'B', 'B', 'B', 'C', 'C', 'C']

if len(mes_reponses) == 15:
    score = sum([1 for i, r in enumerate(mes_reponses) if r.upper() == reponses_correctes[i]])
    print(f"Votre score : {score}/15")
    
    if score >= 13:
        print("\n🎉 Excellent ! Vous maîtrisez le chapitre !")
    elif score >= 10:
        print("\n✅ Bien ! Relisez les sections où vous avez des lacunes.")
    elif score >= 7:
        print("\n⚠️  Moyen. Relisez le chapitre attentivement.")
    else:
        print("\n❌ Insuffisant. Reprenez le chapitre depuis le début.")
    
    # Afficher les erreurs
    print("\nDétail :")
    for i, (ma_rep, bonne_rep) in enumerate(zip(mes_reponses, reponses_correctes), 1):
        if ma_rep.upper() == bonne_rep:
            print(f"Q{i}: ✓ Correct")
        else:
            print(f"Q{i}: ✗ Votre réponse: {ma_rep}, Correcte: {bonne_rep}")
else:
    print("Veuillez remplir toutes les réponses (15 lettres A, B, C ou D)")

# %% [markdown]
# ---
#
# ## Explications des Réponses
#
# ### Q1 : D
# **FAUX** : Le ML inverse le paradigme - il apprend les règles à partir des données, sans programmation explicite.
#
# ### Q2 : B
# L'apprentissage supervisé nécessite des **labels** (étiquettes) pour chaque exemple d'entraînement.
#
# ### Q3 : A
# **Régression** = prédire une valeur numérique continue (prix, température). **Classification** = prédire une catégorie (spam/non-spam, chien/chat).
#
# ### Q4 : B
# L'apprentissage **non-supervisé** n'utilise PAS de labels - il cherche des patterns dans les données.
#
# ### Q5 : B
# On divise les données pour **éviter l'overfitting** et **évaluer objectivement** le modèle sur des données qu'il n'a jamais vues.
#
# ### Q6 : C
# **Overfitting** = le modèle "mémorise" les données d'entraînement mais ne généralise pas bien (haute perf train, faible perf test).
#
# ### Q7 : B
# **Paramètres** : appris par le modèle (poids, biais). **Hyperparamètres** : choisis par le développeur (learning rate, nombre de couches).
#
# ### Q8 : B
# **Feature engineering** = créer ou transformer des features pour améliorer la performance du modèle.
#
# ### Q9 : B
# Le **Deep Learning** apprend les features automatiquement (vs ML classique qui nécessite feature engineering manuel).
#
# ### Q10 : B
# L'**apprentissage par renforcement** utilise des **récompenses et pénalités** pour guider l'agent.
#
# ### Q11 : B
# Pipeline typique : Données → Préparation → Features → Modèle → Évaluation (puis Déploiement).
#
# ### Q12 : B
# **Biais élevé** = modèle trop simple, **underfitting** (ne capture pas la complexité des données).
#
# ### Q13 : C
# Les biais dans les données sont **appris et amplifiés** par le modèle, conduisant à des décisions injustes.
#
# ### Q14 : C
# La **validation croisée** donne une **estimation plus robuste** de la performance en utilisant plusieurs train/val splits.
#
# ### Q15 : C
# **Calcul d'une somme** = opération déterministe simple, pas besoin de ML. Les autres sont des applications typiques du ML.

# %% [markdown]
# ---
#
# ## Prochaines Étapes
#
# - **Score < 10** : Relisez le chapitre 00 attentivement
# - **Score >= 10** : Passez au Chapitre 01 (Fondamentaux Mathématiques)
# - **Révision recommandée** : Refaites le quiz dans 2-3 jours pour ancrer les connaissances

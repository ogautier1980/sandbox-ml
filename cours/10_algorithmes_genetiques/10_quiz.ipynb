# %% [markdown]
# # Quiz d'Auto-Évaluation - Chapitre 10 : Algorithmes Génétiques
#
# **Instructions** :
# - Ce quiz contient 15 questions pour tester votre compréhension du chapitre
# - Répondez aux questions par vous-même avant de regarder les réponses
# - Les réponses sont dans une cellule masquée à la fin
# - Comptez 1 point par bonne réponse
#
# **Barème** :
# - 13-15 : Excellent ! Vous maîtrisez le chapitre 💪
# - 10-12 : Bien, relisez les sections où vous avez des lacunes
# - 7-9 : Moyen, relisez le chapitre attentivement
# - < 7 : Insuffisant, reprenez le chapitre depuis le début
#
# ---

# %% [markdown]
# ## Questions
#
# ### Question 1 : Inspiration Biologique
# Les algorithmes génétiques s'inspirent de l'évolution naturelle. Parmi ces concepts, lequel N'EST PAS un élément fondamental des AG ?
#
# A) Population
# B) Fitness (qualité d'une solution)
# C) Sélection naturelle
# D) Backpropagation
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 2 : Quand Utiliser les AG ?
# Dans quelle situation les algorithmes génétiques sont-ils particulièrement adaptés ?
#
# A) Quand la fonction objectif est différentiable partout
# B) Quand l'espace de recherche est discret ou combinatoire
# C) Quand on a peu de temps de calcul
# D) Quand la descente de gradient fonctionne bien
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 3 : Représentation (Chromosome)
# Quelle représentation est la PLUS appropriée pour résoudre le problème du voyageur de commerce (TSP) ?
#
# A) Encodage binaire
# B) Encodage réel
# C) Permutation
# D) Arbre de décision
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 4 : Sélection Proportionnelle (Roulette Wheel)
# Dans la sélection par roulette, la probabilité de sélectionner un individu $i$ est :
#
# A) $P(i) = f_i$
# B) $P(i) = \frac{f_i}{\sum_j f_j}$
# C) $P(i) = \frac{1}{N}$ (uniforme)
# D) $P(i) = \max(f_i)$
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 5 : Tournament Selection
# Dans la sélection par tournoi (tournament selection), on :
#
# A) Compare tous les individus entre eux
# B) Choisit $k$ individus aléatoirement et sélectionne le meilleur
# C) Sélectionne uniquement le meilleur de la population
# D) Utilise une distribution gaussienne
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 6 : One-Point Crossover
# Dans le one-point crossover, on coupe les deux chromosomes parents à un point aléatoire. Combien d'enfants sont généralement produits ?
#
# A) 1 enfant
# B) 2 enfants
# C) 3 enfants
# D) Autant que la taille de la population
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 7 : Uniform Crossover
# Dans le uniform crossover, chaque gène de l'enfant :
#
# A) Vient toujours du parent 1
# B) Est une moyenne des deux parents
# C) A 50% de chance de venir de chaque parent
# D) Est choisi par tournoi
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 8 : Mutation Binaire (Bit Flip)
# Le taux de mutation recommandé pour un chromosome binaire de longueur $L$ est généralement :
#
# A) $p_m = 1$
# B) $p_m = 1/L$
# C) $p_m = 0.5$
# D) $p_m = 0$ (pas de mutation)
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 9 : Mutation Gaussienne
# Pour un encodage réel, la mutation gaussienne modifie un gène $x$ selon :
#
# A) $x' = x + 1$
# B) $x' = x \times \mathcal{N}(0, \sigma^2)$
# C) $x' = x + \mathcal{N}(0, \sigma^2)$
# D) $x' = \mathcal{N}(0, \sigma^2)$
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 10 : Fonction Fitness pour TSP
# Pour le problème du voyageur de commerce (TSP), une fonction fitness appropriée est :
#
# A) La distance totale du parcours
# B) L'inverse de la distance totale (1/distance)
# C) Le nombre de villes visitées
# D) Le temps de calcul
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 11 : Hyperparamètres d'un AG
# Parmi ces paramètres, lequel N'EST PAS un hyperparamètre typique d'un algorithme génétique ?
#
# A) Taille de la population
# B) Taux de crossover
# C) Taux de mutation
# D) Learning rate
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 12 : CMA-ES
# CMA-ES (Covariance Matrix Adaptation Evolution Strategy) est particulièrement efficace pour :
#
# A) L'optimisation combinatoire uniquement
# B) L'optimisation continue (variables réelles)
# C) L'optimisation binaire uniquement
# D) La classification d'images
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 13 : NSGA-II
# NSGA-II (Non-dominated Sorting Genetic Algorithm) est utilisé pour :
#
# A) L'optimisation mono-objectif rapide
# B) L'optimisation multi-objectifs (Pareto-optimal)
# C) Remplacer la descente de gradient
# D) Uniquement les problèmes de classification
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 14 : Avantages des AG
# Quel est un avantage MAJEUR des algorithmes génétiques par rapport aux méthodes basées gradient ?
#
# A) Convergence plus rapide
# B) Pas besoin de calculer le gradient (fonction non différentiable OK)
# C) Moins de paramètres à tuner
# D) Garantie de trouver l'optimum global
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 15 : Limites des AG
# Quelle est une limitation importante des algorithmes génétiques ?
#
# A) Ils ne peuvent traiter que des problèmes binaires
# B) Ils nécessitent toujours un gradient
# C) Pas de garantie de convergence vers l'optimum global
# D) Ils ne fonctionnent que pour la régression linéaire
#
# **Votre réponse** : ___

# %% [markdown]
# ---
#
# ## Auto-Correction
#
# Avant de regarder les réponses, comptez combien de réponses vous avez données.

# %%
# Entrez vos réponses ici (ex: ['D', 'B', 'C', ...])
mes_reponses = []  # TODO: remplir avec vos réponses

# Réponses correctes (masquées)
reponses_correctes = ['D', 'B', 'C', 'B', 'B', 'B', 'C', 'B', 'C', 'B', 'D', 'B', 'B', 'B', 'C']

if len(mes_reponses) == 15:
    score = sum([1 for i, r in enumerate(mes_reponses) if r.upper() == reponses_correctes[i]])
    print(f"Votre score : {score}/15")
    
    if score >= 13:
        print("\n🎉 Excellent ! Vous maîtrisez le chapitre !")
    elif score >= 10:
        print("\n✅ Bien ! Relisez les sections où vous avez des lacunes.")
    elif score >= 7:
        print("\n⚠️  Moyen. Relisez le chapitre attentivement.")
    else:
        print("\n❌ Insuffisant. Reprenez le chapitre depuis le début.")
    
    # Afficher les erreurs
    print("\nDétail :")
    for i, (ma_rep, bonne_rep) in enumerate(zip(mes_reponses, reponses_correctes), 1):
        if ma_rep.upper() == bonne_rep:
            print(f"Q{i}: ✓ Correct")
        else:
            print(f"Q{i}: ✗ Votre réponse: {ma_rep}, Correcte: {bonne_rep}")
else:
    print("Veuillez remplir toutes les réponses (15 lettres A, B, C ou D)")

# %% [markdown]
# ---
#
# ## Explications des Réponses
#
# ### Q1 : D
# La **backpropagation** est une technique d'entraînement des réseaux de neurones, pas un concept des algorithmes génétiques. Les AG utilisent : population, fitness, sélection, crossover, mutation.
#
# ### Q2 : B
# Les AG sont particulièrement adaptés aux **espaces de recherche discrets ou combinatoires** où les méthodes gradient ne fonctionnent pas (fonction non différentiable, espace discret).
#
# ### Q3 : C
# Pour le TSP, on utilise une **permutation** des villes (ex: [3, 1, 4, 2] signifie visiter ville 3 → 1 → 4 → 2). L'encodage binaire ou réel ne peut pas représenter naturellement un ordre de visite.
#
# ### Q4 : B
# Dans la sélection par roulette, $P(i) = \frac{f_i}{\sum_j f_j}$ : la probabilité est proportionnelle au fitness relatif de l'individu.
#
# ### Q5 : B
# Tournament selection : on **choisit $k$ individus aléatoirement et sélectionne le meilleur** parmi eux. Simple et efficace.
#
# ### Q6 : B
# Le one-point crossover produit généralement **2 enfants** : un avec la première partie du parent 1 + deuxième partie du parent 2, et vice-versa.
#
# ### Q7 : C
# Dans le uniform crossover, **chaque gène a 50% de chance de venir de chaque parent** (décision indépendante pour chaque gène).
#
# ### Q8 : B
# Le taux de mutation recommandé est $p_m = \frac{1}{L}$ où $L$ est la longueur du chromosome. Cela donne en moyenne 1 mutation par chromosome.
#
# ### Q9 : C
# La mutation gaussienne pour un gène réel : $x' = x + \mathcal{N}(0, \sigma^2)$ (on ajoute un bruit gaussien).
#
# ### Q10 : B
# Pour le TSP, on veut **maximiser** le fitness, donc on utilise $\text{fitness} = \frac{1}{\text{distance totale}}$ : plus la distance est courte, plus le fitness est élevé.
#
# ### Q11 : D
# Le **learning rate** est un hyperparamètre de la descente de gradient, pas des algorithmes génétiques. Les AG ont : taille population, taux crossover, taux mutation, nombre de générations.
#
# ### Q12 : B
# CMA-ES est une méthode évolutionnaire très performante pour **l'optimisation continue** (variables réelles), utilisant l'adaptation de la matrice de covariance.
#
# ### Q13 : B
# NSGA-II est conçu pour **l'optimisation multi-objectifs** (plusieurs fonctions à optimiser simultanément), recherchant des solutions Pareto-optimales.
#
# ### Q14 : B
# Un avantage majeur : **pas besoin de gradient**. Les AG fonctionnent avec des fonctions non différentiables, discrètes, bruitées, etc.
#
# ### Q15 : C
# Une limite importante : **pas de garantie de convergence vers l'optimum global**. Les AG sont des métaheuristiques sans garantie théorique de convergence.

# %% [markdown]
# ---
#
# ## Prochaines Étapes
#
# - **Score < 10** : Relisez le chapitre 10 attentivement
# - **Score >= 10** : Passez au Chapitre 11 (Séries Temporelles)
# - **Révision recommandée** : Refaites le quiz dans 2-3 jours pour ancrer les connaissances
# - **Pratique** : Implémentez un AG simple pour résoudre un problème d'optimisation (voir notebooks)

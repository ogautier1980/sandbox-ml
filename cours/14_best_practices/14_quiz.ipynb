# %% [markdown]
# # Quiz d'Auto-Évaluation - Chapitre 14 : Best Practices en Machine Learning
#
# **Instructions** :
# - Ce quiz contient 15 questions pour tester votre compréhension du chapitre
# - Répondez aux questions par vous-même avant de regarder les réponses
# - Les réponses sont dans une cellule masquée à la fin
# - Comptez 1 point par bonne réponse
#
# **Barème** :
# - 13-15 : Excellent ! Vous maîtrisez le chapitre 💪
# - 10-12 : Bien, relisez les sections où vous avez des lacunes
# - 7-9 : Moyen, relisez le chapitre attentivement
# - < 7 : Insuffisant, reprenez le chapitre depuis le début
#
# ---

# %% [markdown]
# ## Questions
#
# ### Question 1 : Workflow ML Standard
# Quel est l'ORDRE CORRECT des étapes dans un workflow ML standard selon le cours ?
#
# A) Modèle → Données → Évaluation → Déploiement
# B) EDA → Preprocessing → Baseline → Itération → Évaluation finale → Déploiement
# C) Baseline → Données → Preprocessing → Modèle → Test
# D) Déploiement → Monitoring → EDA → Modèle
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 2 : Feature Scaling
# Quelle méthode de scaling est la PLUS appropriée en présence d'outliers ?
#
# A) StandardScaler
# B) MinMaxScaler
# C) RobustScaler
# D) Aucune, ne pas scaler
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 3 : Data Leakage
# Quelle pratique est un exemple de DATA LEAKAGE ?
#
# A) Utiliser la validation croisée
# B) Fitter le scaler sur le train set uniquement
# C) Fitter le scaler sur toutes les données (train + test)
# D) Séparer les données en train/test avec un random seed fixe
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 4 : Baseline Model
# Pourquoi est-il important de toujours commencer par un modèle baseline simple ?
#
# A) C'est obligatoire en ML
# B) Pour avoir un point de référence et savoir si les modèles complexes apportent de la valeur
# C) Pour accélérer l'entraînement
# D) Pour réduire l'overfitting
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 5 : Validation Croisée
# Pour un problème de classification avec des classes déséquilibrées, quelle stratégie de cross-validation est recommandée ?
#
# A) KFold classique
# B) StratifiedKFold
# C) TimeSeriesSplit
# D) Leave-One-Out
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 6 : Choix de Métrique
# Dans un contexte où les FAUX NÉGATIFS sont très coûteux (ex: détection de maladies), quelle métrique privilégier ?
#
# A) Precision
# B) Recall
# C) Accuracy
# D) F1-score
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 7 : Hyperparameter Tuning
# Quelle méthode d'hyperparameter tuning est généralement PLUS efficace que Grid Search selon les recherches de Bergstra & Bengio (2012) ?
#
# A) Manual tuning
# B) Random Search
# C) Augmenter le nombre d'epochs
# D) Utiliser les hyperparamètres par défaut
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 8 : Diagnostic Overfitting/Underfitting
# Un modèle a un train error de 15% et un validation error de 16%. Quel est le diagnostic ?
#
# A) Overfitting sévère
# B) Underfitting
# C) Good fit (bon équilibre)
# D) Data leakage
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 9 : Régularisation
# Parmi les techniques suivantes, laquelle N'est PAS une méthode de régularisation ?
#
# A) Dropout
# B) L2 regularization (Ridge)
# C) Early stopping
# D) Augmenter le learning rate
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 10 : Sauvegarde de Modèle
# Quelle bibliothèque Python est recommandée dans le cours pour sauvegarder des modèles scikit-learn ?
#
# A) pickle
# B) json
# C) joblib
# D) numpy.save
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 11 : Déploiement API
# Quel framework Python est utilisé dans le cours pour créer une API REST de prédiction ?
#
# A) Flask
# B) Django
# C) FastAPI
# D) Streamlit
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 12 : Reproductibilité
# Pour assurer la reproductibilité des résultats, quelle pratique est ESSENTIELLE ?
#
# A) Utiliser toujours le même algorithme
# B) Fixer les random seeds (numpy, torch, random)
# C) Entraîner sur GPU uniquement
# D) Utiliser un batch size de 32
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 13 : Test Set
# Quelle affirmation sur le test set est CORRECTE ?
#
# A) On peut tuner les hyperparamètres sur le test set
# B) On doit regarder le test set régulièrement pendant l'entraînement
# C) Le test set doit rester inviolé jusqu'à l'évaluation finale
# D) Le test set peut être utilisé pour la validation croisée
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 14 : Monitoring en Production
# Pourquoi est-il important de monitorer les performances d'un modèle en production ?
#
# A) Pour augmenter la précision automatiquement
# B) Pour détecter le drift (dégradation) et savoir quand réentraîner
# C) Pour réduire les coûts de serveur
# D) Pour accélérer les prédictions
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 15 : Feature Engineering
# Pour les variables catégorielles avec HAUTE cardinalité (beaucoup de catégories), quelle méthode d'encoding est recommandée ?
#
# A) One-Hot Encoding
# B) Label Encoding
# C) Target Encoding
# D) Binary Encoding
#
# **Votre réponse** : ___

# %% [markdown]
# ---
#
# ## Auto-Correction
#
# Avant de regarder les réponses, comptez combien de réponses vous avez données.

# %%
# Entrez vos réponses ici (ex: ['B', 'C', 'C', ...])
mes_reponses = []  # TODO: remplir avec vos réponses

# Réponses correctes (masquées)
reponses_correctes = ['B', 'C', 'C', 'B', 'B', 'B', 'B', 'C', 'D', 'C', 'C', 'B', 'C', 'B', 'C']

if len(mes_reponses) == 15:
    score = sum([1 for i, r in enumerate(mes_reponses) if r.upper() == reponses_correctes[i]])
    print(f"Votre score : {score}/15")
    
    if score >= 13:
        print("\n🎉 Excellent ! Vous maîtrisez le chapitre !")
    elif score >= 10:
        print("\n✅ Bien ! Relisez les sections où vous avez des lacunes.")
    elif score >= 7:
        print("\n⚠️  Moyen. Relisez le chapitre attentivement.")
    else:
        print("\n❌ Insuffisant. Reprenez le chapitre depuis le début.")
    
    # Afficher les erreurs
    print("\nDétail :")
    for i, (ma_rep, bonne_rep) in enumerate(zip(mes_reponses, reponses_correctes), 1):
        if ma_rep.upper() == bonne_rep:
            print(f"Q{i}: ✓ Correct")
        else:
            print(f"Q{i}: ✗ Votre réponse: {ma_rep}, Correcte: {bonne_rep}")
else:
    print("Veuillez remplir toutes les réponses (15 lettres A, B, C ou D)")

# %% [markdown]
# ---
#
# ## Explications des Réponses
#
# ### Q1 : B
# Le workflow correct est : **EDA** (Exploratory Data Analysis) → **Preprocessing** → **Baseline** → **Itération** (modèles + tuning) → **Évaluation finale** → **Déploiement**.
#
# ### Q2 : C
# **RobustScaler** utilise la médiane et l'IQR (Interquartile Range) au lieu de la moyenne et l'écart-type, ce qui le rend robuste aux outliers.
#
# ### Q3 : C
# Fitter le scaler sur **toutes les données** (train + test) est un exemple classique de **data leakage** : le modèle "voit" indirectement le test set via les statistiques du scaler.
#
# ### Q4 : B
# Un **baseline** simple fournit un **point de référence** pour évaluer si les modèles complexes apportent réellement de la valeur, et aide à éviter de sur-complexifier inutilement.
#
# ### Q5 : B
# **StratifiedKFold** préserve les proportions des classes dans chaque fold, ce qui est crucial pour les classes déséquilibrées.
#
# ### Q6 : B
# **Recall** mesure la capacité à détecter tous les positifs. Un haut recall minimise les **faux négatifs** (ex: ne pas rater une maladie grave).
#
# ### Q7 : B
# **Random Search** est plus efficace que Grid Search selon Bergstra & Bengio (2012) car il explore mieux l'espace des hyperparamètres avec moins d'essais.
#
# ### Q8 : C
# Train error ≈ validation error et tous deux raisonnables indique un **good fit** (bon équilibre biais-variance).
#
# ### Q9 : D
# **Augmenter le learning rate** n'est PAS une technique de régularisation. Au contraire, cela peut augmenter l'overfitting. Dropout, L2 et early stopping sont des méthodes de régularisation.
#
# ### Q10 : C
# **joblib** est recommandé pour sauvegarder des modèles scikit-learn car il est plus efficace que pickle pour les gros objets NumPy.
#
# ### Q11 : C
# **FastAPI** est utilisé dans le cours pour créer des APIs REST modernes avec validation automatique (Pydantic) et documentation interactive.
#
# ### Q12 : B
# **Fixer les random seeds** (numpy, torch, random) est essentiel pour garantir que les résultats soient reproductibles d'une exécution à l'autre.
#
# ### Q13 : C
# Le test set doit rester **inviolé** jusqu'à l'évaluation finale. Toute optimisation doit se faire sur train/validation uniquement.
#
# ### Q14 : B
# Le monitoring permet de détecter le **drift** (décalage des distributions de données) et la dégradation des performances, indiquant quand **réentraîner** le modèle.
#
# ### Q15 : C
# **Target Encoding** est recommandé pour les variables catégorielles à haute cardinalité car il encode chaque catégorie par la moyenne du target, créant une seule feature au lieu de centaines avec One-Hot.

# %% [markdown]
# ---
#
# ## Prochaines Étapes
#
# - **Score < 10** : Relisez le chapitre 14 attentivement, en particulier les sections sur data leakage, validation et déploiement
# - **Score >= 10** : Félicitations ! Vous maîtrisez les best practices ML
# - **Révision recommandée** : Pratiquez avec les notebooks `14_demo_pipeline_complet.ipynb`, `14_demo_deployment_fastapi.ipynb` et `14_demo_monitoring_mlflow.ipynb`
# - **Projet final** : Construisez un pipeline ML complet de bout en bout en appliquant toutes ces bonnes pratiques

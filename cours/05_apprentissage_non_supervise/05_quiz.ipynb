# %% [markdown]
# # Quiz d'Auto-Évaluation - Chapitre 05 : Apprentissage Non-Supervisé
#
# **Instructions** :
# - Ce quiz contient 15 questions pour tester votre compréhension du chapitre
# - Répondez aux questions par vous-même avant de regarder les réponses
# - Les réponses sont dans une cellule masquée à la fin
# - Comptez 1 point par bonne réponse
#
# **Barème** :
# - 13-15 : Excellent ! Vous maîtrisez le chapitre 💪
# - 10-12 : Bien, relisez les sections où vous avez des lacunes
# - 7-9 : Moyen, relisez le chapitre attentivement
# - < 7 : Insuffisant, reprenez le chapitre depuis le début
#
# ---

# %% [markdown]
# ## Questions
#
# ### Question 1 : Définition
# Quelle est la caractéristique principale de l'apprentissage non-supervisé ?
#
# A) Il nécessite beaucoup de données étiquetées
# B) Il découvre des structures dans des données non étiquetées
# C) Il est toujours plus rapide que l'apprentissage supervisé
# D) Il ne fonctionne qu'avec des images
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 2 : K-Means - Objectif
# Que cherche à minimiser l'algorithme K-Means ?
#
# A) Le nombre de clusters
# B) La somme des distances carrées au centroïde (inertie)
# C) La distance maximale entre clusters
# D) Le nombre d'itérations
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 3 : K-Means - Complexité
# Quelle est la complexité de K-Means par itération ?
#
# A) $O(n)$
# B) $O(nK)$
# C) $O(nKd)$ où $d$ est la dimension
# D) $O(n^2)$
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 4 : K-Means - Limite
# Quelle affirmation sur K-Means est VRAIE ?
#
# A) K-Means détecte automatiquement le nombre optimal de clusters
# B) K-Means suppose des clusters sphériques et de taille similaire
# C) K-Means ne nécessite pas de normalisation
# D) K-Means converge toujours vers l'optimum global
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 5 : Méthode du Coude (Elbow Method)
# La méthode du coude sert à :
#
# A) Accélérer l'algorithme K-Means
# B) Choisir le nombre optimal de clusters $K$
# C) Normaliser les données
# D) Détecter les outliers
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 6 : DBSCAN - Principe
# DBSCAN se base sur quelle notion pour former les clusters ?
#
# A) Les centroïdes
# B) La densité des points
# C) La hiérarchie
# D) La variance
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 7 : DBSCAN - Avantages
# Quel est un AVANTAGE de DBSCAN par rapport à K-Means ?
#
# A) Plus rapide
# B) Détecte automatiquement les outliers
# C) Toujours meilleure performance
# D) Ne nécessite aucun hyperparamètre
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 8 : Clustering Hiérarchique
# Dans le clustering hiérarchique agglomératif, on :
#
# A) Commence avec 1 cluster et divise itérativement
# B) Commence avec $n$ clusters (1 point chacun) et fusionne itérativement
# C) Utilise la densité pour former les clusters
# D) Minimise l'inertie comme K-Means
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 9 : PCA - Objectif
# Que cherche à préserver la PCA (Principal Component Analysis) ?
#
# A) La distance euclidienne entre tous les points
# B) La variance maximale des données
# C) Le nombre de features
# D) Les clusters naturels
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 10 : PCA - Méthode
# La PCA est basée sur :
#
# A) Le clustering des features
# B) La décomposition en valeurs propres de la matrice de covariance
# C) La descente de gradient
# D) Les arbres de décision
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 11 : PCA - Limitation
# Quelle est une limitation MAJEURE de la PCA ?
#
# A) Elle est très lente
# B) Elle ne fonctionne que pour la classification
# C) C'est une transformation linéaire uniquement
# D) Elle augmente toujours la dimension
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 12 : t-SNE
# Quelle affirmation sur t-SNE est CORRECTE ?
#
# A) t-SNE est une méthode linéaire comme PCA
# B) t-SNE préserve principalement les structures locales (voisinages)
# C) t-SNE peut facilement projeter de nouvelles données
# D) t-SNE est plus rapide que PCA
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 13 : PCA vs t-SNE
# Pour quel usage t-SNE est-il PRINCIPALEMENT conçu ?
#
# A) Preprocessing avant un algorithme de ML
# B) Compression de données
# C) Visualisation de données haute dimension
# D) Détection d'anomalies
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 14 : Détection d'Anomalies - Isolation Forest
# Comment Isolation Forest identifie-t-il les anomalies ?
#
# A) Par leur faible densité
# B) Par leur distance au centroïde
# C) Par le nombre de splits nécessaires pour les isoler (anomalies nécessitent moins de splits)
# D) Par leur variance
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 15 : Comparaison Algorithmes
# Pour visualiser un dataset de 10,000 images haute dimension (784 features), quelle combinaison est la PLUS adaptée ?
#
# A) K-Means seul
# B) PCA (réduction à 50 dims) puis t-SNE (projection 2D)
# C) t-SNE directement sur 784 features
# D) DBSCAN seul
#
# **Votre réponse** : ___

# %% [markdown]
# ---
#
# ## Auto-Correction
#
# Avant de regarder les réponses, comptez combien de réponses vous avez données.

# %%
# Entrez vos réponses ici (ex: ['D', 'B', 'A', ...])
mes_reponses = []  # TODO: remplir avec vos réponses

# Réponses correctes (masquées)
reponses_correctes = ['B', 'B', 'C', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'C', 'B', 'C', 'C', 'B']

if len(mes_reponses) == 15:
    score = sum([1 for i, r in enumerate(mes_reponses) if r.upper() == reponses_correctes[i]])
    print(f"Votre score : {score}/15")
    
    if score >= 13:
        print("\n🎉 Excellent ! Vous maîtrisez le chapitre !")
    elif score >= 10:
        print("\n✅ Bien ! Relisez les sections où vous avez des lacunes.")
    elif score >= 7:
        print("\n⚠️  Moyen. Relisez le chapitre attentivement.")
    else:
        print("\n❌ Insuffisant. Reprenez le chapitre depuis le début.")
    
    # Afficher les erreurs
    print("\nDétail :")
    for i, (ma_rep, bonne_rep) in enumerate(zip(mes_reponses, reponses_correctes), 1):
        if ma_rep.upper() == bonne_rep:
            print(f"Q{i}: ✓ Correct")
        else:
            print(f"Q{i}: ✗ Votre réponse: {ma_rep}, Correcte: {bonne_rep}")
else:
    print("Veuillez remplir toutes les réponses (15 lettres A, B, C ou D)")

# %% [markdown]
# ---
#
# ## Explications des Réponses
#
# ### Q1 : B
# L'apprentissage **non-supervisé** découvre des structures (clusters, dimensions, anomalies) dans des données **sans labels**.
#
# ### Q2 : B
# K-Means minimise l'**inertie** = somme des distances carrées au centroïde : $J = \sum_{k=1}^K \sum_{x \in C_k} \|x - \mu_k\|^2$.
#
# ### Q3 : C
# Complexité par itération : **$O(nKd)$** où $n$ = nombre de points, $K$ = nombre de clusters, $d$ = dimension.
#
# ### Q4 : B
# K-Means suppose des clusters **sphériques** (forme circulaire) et de **taille similaire**. C'est une limitation majeure.
#
# ### Q5 : B
# La **méthode du coude** trace l'inertie en fonction de $K$ et cherche le "coude" de la courbe pour choisir le $K$ optimal.
#
# ### Q6 : B
# DBSCAN (Density-Based) forme les clusters basés sur la **densité** des points : points densément connectés = cluster.
#
# ### Q7 : B
# DBSCAN **détecte automatiquement les outliers** (points marqués comme "noise"). K-Means assigne tous les points à un cluster.
#
# ### Q8 : B
# **Agglomératif** (bottom-up) : commence avec $n$ clusters (1 point chacun) et **fusionne** itérativement. L'opposé est **divisif** (top-down).
#
# ### Q9 : B
# PCA cherche à préserver la **variance maximale** : projeter les données sur les directions de plus grande variance.
#
# ### Q10 : B
# PCA = **décomposition en valeurs propres** de la matrice de covariance. Les vecteurs propres = composantes principales.
#
# ### Q11 : C
# PCA est une transformation **linéaire** uniquement. Pour relations non-linéaires, utiliser Kernel PCA, t-SNE ou UMAP.
#
# ### Q12 : B
# t-SNE préserve les **structures locales** (voisinages) via minimisation de divergence KL. C'est une méthode **non-linéaire**.
#
# ### Q13 : C
# t-SNE est conçu pour la **visualisation** (projection 2D/3D). Pour preprocessing, utiliser PCA (plus rapide, déterministe).
#
# ### Q14 : C
# Isolation Forest : les anomalies sont **faciles à isoler** (nécessitent moins de splits dans les arbres aléatoires).
#
# ### Q15 : B
# Pour haute dimension ($d > 50$), faire **PCA d'abord** (réduction rapide) puis **t-SNE** (visualisation). t-SNE direct sur 784 dims est très lent et peu efficace.

# %% [markdown]
# ---
#
# ## Prochaines Étapes
#
# - **Score < 10** : Relisez le chapitre 05 attentivement
# - **Score >= 10** : Passez au Chapitre 06 (Réseaux de Neurones Fondamentaux)
# - **Révision recommandée** : Refaites le quiz dans 2-3 jours pour ancrer les connaissances

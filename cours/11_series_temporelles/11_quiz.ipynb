# %% [markdown]
# # Quiz d'Auto-Évaluation - Chapitre 11 : Séries Temporelles et Forecasting
#
# **Instructions** :
# - Ce quiz contient 15 questions pour tester votre compréhension du chapitre
# - Répondez aux questions par vous-même avant de regarder les réponses
# - Les réponses sont dans une cellule masquée à la fin
# - Comptez 1 point par bonne réponse
#
# **Barème** :
# - 13-15 : Excellent ! Vous maîtrisez le chapitre 💪
# - 10-12 : Bien, relisez les sections où vous avez des lacunes
# - 7-9 : Moyen, relisez le chapitre attentivement
# - < 7 : Insuffisant, reprenez le chapitre depuis le début
#
# ---

# %% [markdown]
# ## Questions
#
# ### Question 1 : Définition Série Temporelle
# Quelle est la différence fondamentale entre une série temporelle et des données ML classiques ?
#
# A) Les séries temporelles ont plus de features
# B) Les observations ont une dépendance temporelle (pas i.i.d.)
# C) Les séries temporelles sont toujours continues
# D) Il n'y a pas de différence
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 2 : Décomposition Additive
# Dans la décomposition additive d'une série temporelle, $y_t = T_t + S_t + R_t$, que représente $S_t$ ?
#
# A) La tendance (trend)
# B) La saisonnalité (seasonality)
# C) Le résidu (residual)
# D) La stationnarité
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 3 : Stationnarité Faible
# Pour qu'une série soit faiblement stationnaire, quelle condition doit être respectée ?
#
# A) La série doit être constante
# B) La moyenne et la variance doivent être constantes dans le temps
# C) Il ne doit pas y avoir de tendance ni de saisonnalité
# D) La série doit être positive
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 4 : Test ADF (Augmented Dickey-Fuller)
# Dans le test ADF, si la p-value est inférieure à 0.05, on conclut que :
#
# A) La série est non-stationnaire
# B) La série est stationnaire
# C) Il faut différencier davantage
# D) La série a une tendance linéaire
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 5 : Différenciation
# Quelle est la différenciation d'ordre 1 de la série temporelle ?
#
# A) $\nabla y_t = y_t + y_{t-1}$
# B) $\nabla y_t = y_t - y_{t-1}$
# C) $\nabla y_t = y_t \times y_{t-1}$
# D) $\nabla y_t = \frac{y_t}{y_{t-1}}$
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 6 : Modèle ARIMA(p,d,q)
# Dans ARIMA(p,d,q), que représente le paramètre $d$ ?
#
# A) L'ordre autorégressif
# B) L'ordre de différenciation
# C) L'ordre moyenne mobile
# D) La durée de prédiction
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 7 : ACF et PACF
# Pour identifier l'ordre $p$ d'un modèle AR(p), on analyse principalement :
#
# A) L'ACF (autocorrélation)
# B) Le PACF (autocorrélation partielle)
# C) La tendance
# D) La variance
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 8 : SARIMA
# SARIMA(1,1,1)(1,1,1,12) est approprié pour des données :
#
# A) Quotidiennes avec saisonnalité hebdomadaire
# B) Mensuelles avec saisonnalité annuelle
# C) Horaires sans saisonnalité
# D) Annuelles
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 9 : Prophet de Facebook
# Quel est un avantage de Prophet par rapport à ARIMA ?
#
# A) Plus rapide à entraîner
# B) Gère nativement les données manquantes et les jours fériés
# C) Nécessite moins de données
# D) Garantit une meilleure précision
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 10 : LSTM pour Forecasting
# Pourquoi les LSTM sont-ils adaptés aux séries temporelles ?
#
# A) Ils sont plus rapides que les modèles classiques
# B) Ils peuvent capturer des dépendances temporelles à long terme
# C) Ils ne nécessitent pas de normalisation
# D) Ils fonctionnent sans données d'entraînement
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 11 : Sliding Windows
# Pour un LSTM avec window size = 5 et une série [1,2,3,4,5,6,7], le premier exemple d'entraînement est :
#
# A) X = [1,2,3,4,5], y = 6
# B) X = [1,2,3], y = [4,5]
# C) X = [1], y = [2,3,4,5,6]
# D) X = [1,2,3,4,5,6,7], y = 7
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 12 : Métriques - MAPE
# La métrique MAPE (Mean Absolute Percentage Error) a un problème quand :
#
# A) Les valeurs prédites sont négatives
# B) Les valeurs réelles sont égales à zéro
# C) La série est stationnaire
# D) Il y a trop de données
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 13 : Time Series Split
# Pourquoi NE DOIT-ON PAS utiliser la validation croisée K-Fold classique pour les séries temporelles ?
#
# A) C'est trop lent
# B) Cela créerait du data leakage (utiliser le futur pour prédire le passé)
# C) Les séries temporelles n'ont pas assez de données
# D) K-Fold ne fonctionne que pour la classification
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 14 : Détection d'Anomalies
# Comment peut-on détecter des anomalies dans une série temporelle avec un modèle de forecasting ?
#
# A) En regardant la moyenne de la série
# B) Si l'erreur de prédiction dépasse un seuil (ex: 3 écarts-types)
# C) En comptant le nombre de valeurs manquantes
# D) En calculant l'autocorrélation
#
# **Votre réponse** : ___

# %% [markdown]
# ### Question 15 : Normalisation
# Lors de la normalisation d'une série temporelle pour LSTM, quelle est la bonne pratique ?
#
# A) Calculer les statistiques (moyenne, écart-type) sur toutes les données
# B) Calculer les statistiques uniquement sur le train set
# C) Ne pas normaliser les séries temporelles
# D) Utiliser toujours MinMaxScaler entre [0,1]
#
# **Votre réponse** : ___

# %% [markdown]
# ---
#
# ## Auto-Correction
#
# Avant de regarder les réponses, comptez combien de réponses vous avez données.

# %%
# Entrez vos réponses ici (ex: ['B', 'B', 'B', ...])
mes_reponses = []  # TODO: remplir avec vos réponses

# Réponses correctes (masquées)
reponses_correctes = ['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'A', 'B', 'B', 'B', 'B']

if len(mes_reponses) == 15:
    score = sum([1 for i, r in enumerate(mes_reponses) if r.upper() == reponses_correctes[i]])
    print(f"Votre score : {score}/15")
    
    if score >= 13:
        print("\n🎉 Excellent ! Vous maîtrisez le chapitre !")
    elif score >= 10:
        print("\n✅ Bien ! Relisez les sections où vous avez des lacunes.")
    elif score >= 7:
        print("\n⚠️  Moyen. Relisez le chapitre attentivement.")
    else:
        print("\n❌ Insuffisant. Reprenez le chapitre depuis le début.")
    
    # Afficher les erreurs
    print("\nDétail :")
    for i, (ma_rep, bonne_rep) in enumerate(zip(mes_reponses, reponses_correctes), 1):
        if ma_rep.upper() == bonne_rep:
            print(f"Q{i}: ✓ Correct")
        else:
            print(f"Q{i}: ✗ Votre réponse: {ma_rep}, Correcte: {bonne_rep}")
else:
    print("Veuillez remplir toutes les réponses (15 lettres A, B, C ou D)")

# %% [markdown]
# ---
#
# ## Explications des Réponses
#
# ### Q1 : B
# Les séries temporelles ont une **dépendance temporelle** : la valeur à l'instant $t$ dépend des valeurs passées. Les données ML classiques sont supposées i.i.d. (indépendantes et identiquement distribuées).
#
# ### Q2 : B
# Dans $y_t = T_t + S_t + R_t$ : $S_t$ = **saisonnalité** (motifs périodiques répétitifs), $T_t$ = tendance, $R_t$ = résidu (bruit).
#
# ### Q3 : B
# Stationnarité faible requiert : **moyenne constante**, **variance constante**, et autocovariance ne dépendant que du lag.
#
# ### Q4 : B
# Test ADF : si **p-value < 0.05**, on rejette $H_0$ (racine unitaire) $\Rightarrow$ **série stationnaire**.
#
# ### Q5 : B
# Différenciation d'ordre 1 : $\nabla y_t = y_t - y_{t-1}$ (différence première, élimine la tendance).
#
# ### Q6 : B
# ARIMA(p,d,q) : $p$ = ordre AR, **$d$ = ordre de différenciation**, $q$ = ordre MA.
#
# ### Q7 : B
# Pour identifier $p$ d'un modèle AR(p), on analyse le **PACF** (autocorrélation partielle) qui coupe après le lag $p$.
#
# ### Q8 : B
# SARIMA(1,1,1)(1,1,1,**12**) : le 12 indique une saisonnalité de période 12, approprié pour **données mensuelles avec saisonnalité annuelle**.
#
# ### Q9 : B
# Prophet **gère nativement les données manquantes et les jours fériés**, contrairement à ARIMA qui nécessite preprocessing.
#
# ### Q10 : B
# Les LSTM ont une **cellule mémoire** qui permet de **capturer des dépendances à long terme** (résout le problème du vanishing gradient des RNN classiques).
#
# ### Q11 : A
# Avec window size = 5 : **X = [1,2,3,4,5], y = 6** (les 5 valeurs passées prédisent la suivante).
#
# ### Q12 : B
# MAPE = $\frac{100\%}{n}\sum |\frac{y_i - \hat{y}_i}{y_i}|$ : **problème si $y_i = 0$** (division par zéro).
#
# ### Q13 : B
# K-Fold aléatoire créerait du **data leakage** : on utiliserait le futur pour prédire le passé. Il faut utiliser Time Series Split.
#
# ### Q14 : B
# Détection d'anomalies : calculer l'erreur de prédiction $e_t = |y_t - \hat{y}_t|$, **anomalie si $e_t > \text{seuil}$** (ex: moyenne + 3 écarts-types).
#
# ### Q15 : B
# **Bonne pratique** : calculer moyenne et écart-type **uniquement sur train set**, puis appliquer la transformation sur train et test (évite le leakage).

# %% [markdown]
# ---
#
# ## Prochaines Étapes
#
# - **Score < 10** : Relisez le chapitre 11 attentivement
# - **Score >= 10** : Passez au Chapitre 12 (Vision Avancée)
# - **Révision recommandée** : Refaites le quiz dans 2-3 jours pour ancrer les connaissances
# - **Pratique** : Implémentez un pipeline ARIMA + LSTM sur un dataset réel (voir notebooks)

# %% [markdown]
# # Exercices : Introduction et Sécurité Parfaite
#
# Ce notebook contient des exercices pratiques pour approfondir les concepts du chapitre 1.

# %% [markdown]
# ## Exercice 1 : Chiffre de César
#
# Implémenter le chiffre de César et montrer expérimentalement qu'il n'a pas la sécurité parfaite.

# %%
# À COMPLÉTER
def caesar_encrypt(plaintext: str, shift: int) -> str:
    """
    Chiffre un message avec le chiffre de César.
    
    Args:
        plaintext: Message en lettres majuscules (A-Z)
        shift: Décalage (0-25)
    
    Returns:
        Ciphertext chiffré
    """
    pass  # À COMPLÉTER

# Test
assert caesar_encrypt("HELLO", 3) == "KHOOR"
print("✅ Test passé")

# %% [markdown]
# ## Exercice 2 : Two-Time Pad Attack avancée
#
# Implémenter une attaque par fréquence sur deux messages anglais chiffrés avec la même clé.

# %%
# À COMPLÉTER
# Indices :
# 1. Espace (' ') XOR lettre donne une lettre avec case inversée
# 2. Chercher patterns de mots communs (THE, AND, etc.)
# 3. Utiliser fréquences des lettres anglaises

# %% [markdown]
# ## Exercice 3 : Malléabilité du OTP
#
# Démontrer qu'un attaquant peut modifier un ciphertext OTP de manière contrôlée.

# %%
# À COMPLÉTER
# Scénario : Message "TRANSFER $1000"
# Objectif : Modifier en "TRANSFER $9999" sans connaître la clé

# %% [markdown]
# ## Exercice 4 : Théorème de Shannon
#
# Vérifier expérimentalement que $|\mathcal{K}| \geq |\mathcal{M}|$ est nécessaire pour la sécurité parfaite.

# %%
# À COMPLÉTER
# Créer un système avec |K| < |M|
# Montrer qu'il existe un ciphertext c et deux messages m1, m2
# tels que Pr[Enc(m1) = c] != Pr[Enc(m2) = c]
